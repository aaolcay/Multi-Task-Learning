# %% [markdown]
# <a href="https://colab.research.google.com/github/aaolcay/Multi-Task-Learning/blob/main/multi_task_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Multi-task Learning**
#
# I am sharing the code below that is on multi-task learning. We use the dataset from the Kaggle, more than 20000 face images, to classify their genders and races.
#
# The code has been written by Abdullah A. Olcay.

# %% [markdown]
# ###**Load Data**

# %%
# Install Kaggle Python library
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
# Mounting Google Drive in Google Colab for Easy File Access
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !pwd
# Out:
# /gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/gdrive/MyDrive/Multi-task Learning/Data'

# %%
# changing the working directory
# %cd '/gdrive/MyDrive/Multi-task Learning/Data'
# Out:
# /gdrive/MyDrive/Multi-task Learning/Data

# %%
# checking the current working directory
# !pwd
# Out:
# /gdrive/MyDrive/Multi-task Learning/Data

# %%
# !kaggle datasets download -d nipunarora8/age-gender-and-ethnicity-face-data-csv
# Out:
# Downloading age-gender-and-ethnicity-face-data-csv.zip to /gdrive/MyDrive/Multi-task Learning/Data
#  92% 58.0M/63.2M [00:00<00:00, 93.1MB/s]
# 100% 63.2M/63.2M [00:00<00:00, 96.2MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  age-gender-and-ethnicity-face-data-csv.zip
# replace age_gender.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: age_gender.csv

# %% [markdown]
# ####**Prepare Data**

# %%
import pandas as pd

# %%
# !ls
# Out:
# age_gender.csv	kaggle.json  model.h5  model.json

# %%
data = pd.read_csv('age_gender.csv')

# %%
data.head(10)
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
# 5    1          2       0  20161220144957407.jpg.chip.jpg
# 6    1          2       0  20161220145040127.jpg.chip.jpg
# 7    1          2       0  20170109191125532.jpg.chip.jpg
# 8    1          2       0  20161219222749039.jpg.chip.jpg
# 9    1          2       0  20170109191209991.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...
# 5  195 198 200 200 198 198 199 199 198 197 197 19...
# 6  208 216 217 219 222 223 222 221 220 220 221 22...
# 7  99 142 169 177 179 181 183 186 187 186 191 190...
# 8  127 127 133 140 143 148 152 157 160 165 172 17...
# 9  199 211 211 214 216 216 219 221 222 224 219 21...

# %%
print("Length of data:", len(data))
# Out:
# Length of data: 23705

# %% [markdown]
# To divide the images into three distinct datasets, namely Train, Dev/Val, and dev sets, we have partitioned the data with the following proportions: 18505 samples for training and 2600 samples for development/validation and 2600 for test data.

# %%
images = data.pixels
type(images[0])
# Out:
# str

# %%
images = images.str.split(" ").tolist()
type(images[0])
# Out:
# list

# %%
ages = data.age.astype('float')
type(ages[0])
# Out:
# numpy.float64

# %%
races = data.ethnicity.astype('float')
type(races[0])
# Out:
# numpy.float64

# %%
genders = data.gender.astype('float')
type(genders[0])
# Out:
# numpy.float64

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.hist(ages, bins=15)
plt.title('Age Distribution in the Data')
plt.ylabel('Number of Samples')
plt.xlabel('Ages')
plt.show()

# %%
import numpy as np
num_genders = len(np.unique(genders))
number_class = np.zeros(num_genders)
for i in range(num_genders):
  number_class[i] = len(np.where(genders==i)[0])
plt.figure()
labels_genders = ['Male', 'Female']
plt.bar(labels_genders, number_class)
plt.title('Gender Distribution in the Data')
plt.ylabel('Number of Samples')
plt.show()

# %%
num_races = len(np.unique(races))
number_class = np.zeros(num_races)
for i in range(num_races):
  number_class[i] = len(np.where(races==i)[0])
plt.figure()
labels_races = ['White', 'Black', 'Asian', 'Indian', 'Others']
plt.bar(labels_races, number_class)
plt.title('Ethnicity Distribution in the Data')
plt.ylabel('Number of Samples')
plt.show()

# %%
images = np.array(images).reshape(-1,48,48,1).astype('float')
data_dict = {
        "images": [],
        "ages": [],
        "genders": [],
        "races": []
    }
for i in range(len(data)):
  data_dict["images"].append(images[i,:])
  data_dict["ages"].append(ages[i])
  data_dict["genders"].append(genders[i])
  data_dict["races"].append(races[i])

# %% [markdown]
# Make each label separate

# %%
label_ages = np.array(data_dict["ages"])
label_genders = np.array(data_dict["genders"])
label_races =  np.array(data_dict["races"])

# %%
random_numbers = np.random.randint(low=0, high=23704, size=20)
fig = plt.figure(figsize=(20,20))
count = 0
for k in random_numbers:
  fig.add_subplot(4,5,count+1)
  plt.imshow(images[k], cmap='gray')
  label_g = labels_genders[int(label_genders[k])]
  label_r = labels_races[int(label_races[k])]
  plt.title(f"Age: {label_ages[k]}, Gender: {label_g}, Ethnicity: {label_r}")
  fig.tight_layout(pad=0.2)
  count += 1

# %%
# Shuffle data
np.random.seed(1)
idx = np.random.permutation(len(data))

# %%
train_label_ages = label_ages[idx[0:18505]]
train_label_genders = label_genders[idx[0:18505]]
train_label_races = label_races[idx[0:18505]]
train_images =images[idx[0:18505],:,:,:]

# %%
val_label_ages = label_ages[idx[18505:18505+2600]]
val_label_genders = label_genders[idx[18505:18505+2600]]
val_label_races = label_races[idx[18505:18505+2600]]
val_images =images[idx[18505:18505+2600],:,:,:]

# %%
test_label_ages = label_ages[idx[18505+2600:18505+2600+2600]]
test_label_genders = label_genders[idx[18505+2600:18505+2600+2600]]
test_label_races = label_races[idx[18505+2600:18505+2600+2600]]
test_images =images[idx[18505+2600:18505+2600+2600],:,:,:]

# %%
num_genders_train = len(np.unique(train_label_genders))
number_class_g_t = np.zeros(num_genders_train)
for i in range(num_genders_train):
  number_class_g_t[i] = len(np.where(train_label_genders==i)[0])

num_races_train = len(np.unique(train_label_races))
number_class_r_t = np.zeros(num_races_train)
for i in range(num_races_train):
  number_class_r_t[i] = len(np.where(train_label_races==i)[0])

fig = plt.figure(figsize=(15,7))
fig.add_subplot(1,3,1)
plt.bar(labels_genders, number_class_g_t)
plt.title('Gender Distribution in Training Dataset')
plt.ylabel('Number of Samples')
fig.add_subplot(1,3,2)
plt.bar(labels_races, number_class_r_t)
plt.title('Ethnicity Distribution in Training Dataset')
plt.ylabel('Number of Samples')
fig.add_subplot(1,3,3)
plt.hist(train_label_ages, bins=15)
plt.title('Age Distribution in Training Dataset')
plt.ylabel('Number of Samples')
plt.xlabel('Ages')
fig.tight_layout(pad=1.5)
plt.show()

# %%
num_genders_val = len(np.unique(val_label_genders))
number_class_g_v = np.zeros(num_genders_val)
for i in range(num_genders_val):
  number_class_g_v[i] = len(np.where(val_label_genders==i)[0])

num_races_val = len(np.unique(val_label_races))
number_class_r_v = np.zeros(num_races_val)
for i in range(num_races_val):
  number_class_r_v[i] = len(np.where(val_label_races==i)[0])

fig = plt.figure(figsize=(15,7))
fig.add_subplot(1,3,1)
plt.bar(labels_genders, number_class_g_v)
plt.title('Gender Distribution in Validation Dataset')
plt.ylabel('Number of Samples')
fig.add_subplot(1,3,2)
plt.bar(labels_races, number_class_r_v)
plt.title('Ethnicity Distribution in Validation Dataset')
plt.ylabel('Number of Samples')
fig.add_subplot(1,3,3)
plt.hist(val_label_ages, bins=15)
plt.title('Age Distribution in Validation Dataset')
plt.ylabel('Number of Samples')
plt.xlabel('Ages')
fig.tight_layout(pad=1.5)
plt.show()

# %%
num_genders_test = len(np.unique(test_label_genders))
number_class_g_t = np.zeros(num_genders_test)
for i in range(num_genders_test):
  number_class_g_t[i] = len(np.where(test_label_genders==i)[0])

num_races_test = len(np.unique(test_label_races))
number_class_r_t = np.zeros(num_races_test)
for i in range(num_races_test):
  number_class_r_t[i] = len(np.where(test_label_races==i)[0])

fig = plt.figure(figsize=(15,7))
fig.add_subplot(1,3,1)
plt.bar(labels_genders, number_class_g_t)
plt.title('Gender Distribution in Test Dataset')
plt.ylabel('Number of Samples')
fig.add_subplot(1,3,2)
plt.bar(labels_races, number_class_r_t)
plt.title('Ethnicity Distribution in Test Dataset')
plt.ylabel('Number of Samples')
fig.add_subplot(1,3,3)
plt.hist(test_label_ages, bins=15)
plt.title('Age Distribution in Test Dataset')
plt.ylabel('Number of Samples')
plt.xlabel('Ages')
fig.tight_layout(pad=1.5)
plt.show()

# %% [markdown]
# Augment Training Data

# %%
from keras.preprocessing.image import ImageDataGenerator

# Assuming you have an original dataset X_train and corresponding labels y_train

# Create the instance of the ImageDataGenerator with desired augmentation settings
datagen1 = ImageDataGenerator(
    rotation_range=10,  # randomly rotate images by 10 degrees
    width_shift_range=0.1,  # randomly shift images horizontally by 10% of the width
    height_shift_range=0.1,  # randomly shift images vertically by 10% of the height
    horizontal_flip=True,  # randomly flip images horizontally
    zoom_range=0.01  # randomly zoom images by 1%
)

# Fit each data generator on your original dataset separately
datagen1.fit(train_images)

# Initialize an empty list to store augmented data and labels
augmented_images = []
augmented_label_ages = []
augmented_label_genders = []
augmented_label_races = []

# Generate augmented samples by applying transformations from the first data generator
for i in range(len(train_images)):
  count = 1
  im = train_images[i, :, :, :]
  im = im[np.newaxis, :]
  for X_batch in datagen1.flow(im, batch_size=1):
      augmented_images.extend(X_batch)
      augmented_label_ages.append(train_label_ages[i])
      augmented_label_genders.append(train_label_genders[i])
      augmented_label_races.append(train_label_races[i])
      count +=1
      if count>2:
        break

# Convert the augmented data and labels to numpy arrays
augmented_images = np.array(augmented_images)
augmented_label_ages = np.array(augmented_label_ages)
augmented_label_genders = np.array(augmented_label_genders)
augmented_label_races = np.array(augmented_label_races)

# Combine the original datasets with augmented data
final_train = np.concatenate((train_images, augmented_images))
final_label_ages = np.concatenate((train_label_ages, augmented_label_ages))
final_label_genders = np.concatenate((train_label_genders, augmented_label_genders))
final_label_races = np.concatenate((train_label_races, augmented_label_races))

# %%
fig = plt.figure(figsize=(20,20))
ind = [0, 18505, 18505+1, 1, 18505+2, 18505+3, 2, 18505+4, 18505+5, 3, 18505+6, 18505+7, 4, 18505+8, 18505+9, 5, 18505+10, 18505+11, 6]
count = 0
for k in ind:
  print(k)
  fig.add_subplot(4,5,count+1)
  plt.imshow(final_train[k], cmap='gray')
  label_g = labels_genders[int(final_label_genders[k])]
  label_r = labels_races[int(final_label_races[k])]
  plt.title(f"Age: {final_label_ages[k]}, Gender: {label_g}, Ethnicity: {label_r}")
  fig.tight_layout(pad=0.2)
  count += 1
# Out:
# 0
# 18505
# 18506
# 1
# 18507
# 18508
# 2
# 18509
# 18510
# 3
# 18511
# 18512
# 4
# 18513
# 18514
# 5
# 18515
# 18516
# 6

# %%
# Shuffle the combined datasets
indices = np.random.permutation(final_train.shape[0])
aug_train = final_train[indices]
aug_label_ages = final_label_ages[indices]
aug_label_genders = final_label_genders[indices]
aug_label_races = final_label_races[indices]

# %%
random_numbers = np.random.randint(low=0, high=55512, size=20)
fig = plt.figure(figsize=(20,20))
count = 0
for k in random_numbers:
  print(k)
  fig.add_subplot(4,5,count+1)
  plt.imshow(aug_train[k], cmap='gray')
  label_g = labels_genders[int(aug_label_genders[k])]
  label_r = labels_races[int(aug_label_races[k])]
  plt.title(f"Age: {aug_label_ages[k]}, Gender: {label_g}, Ethnicity: {label_r}")
  fig.tight_layout(pad=0.2)
  count += 1
# Out:
# 2866
# 44359
# 1669
# 39712
# 42113
# 36264
# 5891
# 33037
# 42199
# 30327
# 27462
# 52007
# 42116
# 9622
# 21409
# 31749
# 38480
# 12498
# 7288
# 48780

# %% [markdown]
# Transfer Learning

# %%
from tensorflow.keras.applications import VGG16

# Load the pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(48, 48, 3))

# Freeze the weights and bias terms in the base model
base_model.trainable = True

# Print the model summary
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow.keras as keras
# Change the fully-connected layer for multi-task learning
# Add our own classification layers
x = keras.layers.GlobalAveragePooling2D()(base_model.output)

# Task specific branches
# ethnicity
ethnicity_output = keras.layers.Dense(64,
                                      activation='relu',
                                      name='ethnicity_dense_1')(x)
ethnicity_output = keras.layers.Dropout(0.5)(ethnicity_output)
ethnicity_output = keras.layers.Dense(5,
                                      activation='softmax',
                                      name='ethnicity_output')(ethnicity_output) # for ethnicity

# gender
gender_output = keras.layers.Dense(64,
                                   activation='relu',
                                   name='gender_dense_1')(x)
gender_output = keras.layers.Dropout(0.5)(gender_output)
gender_output = keras.layers.Dense(1, activation='sigmoid', name='gender_output')(gender_output) # for gender

# Multi-task Classifier (Model)
model = keras.models.Model(inputs=base_model.input, outputs=[ethnicity_output, gender_output])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 48, 48, 64)   36928       ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)     (None, 24, 24, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 24, 24, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 24, 24, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 12, 12, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 12, 12, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 12, 12, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 12, 12, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 6, 6, 256)    0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 6, 6, 512)    1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 6, 6, 512)    2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 6, 6, 512)    2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 3, 3, 512)    0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 3, 3, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 3, 3, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 3, 3, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 1, 1, 512)    0           ['block5_conv3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['block5_pool[0][0]']
#  alAveragePooling2D)
#
#  ethnicity_dense_1 (Dense)      (None, 64)           32832       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  gender_dense_1 (Dense)         (None, 64)           32832       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 64)           0           ['ethnicity_dense_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['gender_dense_1[0][0]']
#
#  ethnicity_output (Dense)       (None, 5)            325         ['dropout[0][0]']
#
#  gender_output (Dense)          (None, 1)            65          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 14,780,742
# Trainable params: 14,780,742
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compile the model
# Specify the loss functions for each output
losses = {
    'ethnicity_output': 'categorical_crossentropy',
    'gender_output': 'binary_crossentropy'
}

# Specify the metrics for each output
metrics = {
    'ethnicity_output': 'accuracy',
    'gender_output': 'accuracy'
}

model.compile(optimizer='adam', loss=losses, metrics=metrics, weighted_metrics=metrics)

# %%
# Convert grayscale images to RGB and scale pixel values
train_rgb_images = np.stack((aug_train,) * 3, axis=-1) / 255.0
val_rgb_images = np.stack((val_images,) * 3, axis=-1) / 255.0
test_rgb_images = np.stack((test_images,) * 3, axis=-1) / 255.0

# Remove extra dimension
train_rgb_images = np.squeeze(train_rgb_images)
val_rgb_images = np.squeeze(val_rgb_images)
test_rgb_images = np.squeeze(test_rgb_images)

# %%
print(f"The shape of train, validation and test iamges:\n train data shape: {train_rgb_images.shape}\n validation data shape: {val_rgb_images.shape}\n test data shape: {test_rgb_images.shape}")
# Out:
# The shape of train, validation and test iamges:
#  train data shape: (55515, 48, 48, 3)
#  validation data shape: (2600, 48, 48, 3)
#  test data shape: (2600, 48, 48, 3)

# %%
random_numbers = np.random.randint(low=0, high=55512, size=20)
fig = plt.figure(figsize=(20,20))
count = 0
for k in random_numbers:
  print(k)
  fig.add_subplot(4,5,count+1)
  plt.imshow(train_rgb_images[k], cmap='gray')
  label_g = labels_genders[int(aug_label_genders[k])]
  label_r = labels_races[int(aug_label_races[k])]
  plt.title(f"Age: {aug_label_ages[k]}, Gender: {label_g}, Ethnicity: {label_r}")
  fig.tight_layout(pad=0.2)
  count += 1
# Out:
# 148
# 20408
# 27593
# 16927
# 48674
# 54529
# 8859
# 14390
# 39762
# 30838
# 8092
# 18577
# 44858
# 12545
# 23800
# 14777
# 22322
# 17028
# 16490
# 44873

# %%
aug_label_races = keras.utils.to_categorical(aug_label_races, 5)
val_label_races = keras.utils.to_categorical(val_label_races, 5)
test_label_races = keras.utils.to_categorical(test_label_races, 5)

# %%
from keras.callbacks import LearningRateScheduler, EarlyStopping

early_stopping = EarlyStopping(monitor='val_gender_output_loss', patience=25)

# Decayin learning rate
"""
def lr_schedule(epoch, lr):
    start_lr = 0.1  # Starting learning rate
    decay_factor = 0.1  # Decay factor
    decay_step = 25    # Decay step

    if epoch != 0 and epoch % decay_step == 0:
      lr = lr * decay_factor
    if epoch == 0:
      lr = start_lr
    return lr
"""

# Create the LearningRateScheduler callback
#lr_scheduler = LearningRateScheduler(lr_schedule)

y_val = {'ethnicity_output': val_label_races, 'gender_output': val_label_genders}
# Train the model
history = model.fit(x=train_rgb_images,
          y={'ethnicity_output': aug_label_races, 'gender_output': aug_label_genders},
          validation_data=(val_rgb_images, y_val),
          batch_size=64,
          epochs=200,
          shuffle=True,
          callbacks=[early_stopping])
          #callbacks=[lr_scheduler])
# Out:
# Epoch 1/200
# 868/868 [==============================] - 75s 66ms/step - loss: 1.8705 - ethnicity_output_loss: 1.2982 - gender_output_loss: 0.5724 - ethnicity_output_accuracy: 0.5027 - ethnicity_output_weighted_accuracy: 0.5027 - gender_output_accuracy: 0.6833 - gender_output_weighted_accuracy: 0.6833 - val_loss: 1.4296 - val_ethnicity_output_loss: 1.0366 - val_gender_output_loss: 0.3930 - val_ethnicity_output_accuracy: 0.6127 - val_ethnicity_output_weighted_accuracy: 0.6127 - val_gender_output_accuracy: 0.8238 - val_gender_output_weighted_accuracy: 0.8238
# Epoch 2/200
# 868/868 [==============================] - 55s 63ms/step - loss: 1.3022 - ethnicity_output_loss: 0.9523 - gender_output_loss: 0.3500 - ethnicity_output_accuracy: 0.6563 - ethnicity_output_weighted_accuracy: 0.6563 - gender_output_accuracy: 0.8499 - gender_output_weighted_accuracy: 0.8499 - val_loss: 1.1044 - val_ethnicity_output_loss: 0.7966 - val_gender_output_loss: 0.3078 - val_ethnicity_output_accuracy: 0.7308 - val_ethnicity_output_weighted_accuracy: 0.7308 - val_gender_output_accuracy: 0.8631 - val_gender_output_weighted_accuracy: 0.8631
# Epoch 3/200
# 868/868 [==============================] - 55s 63ms/step - loss: 1.0372 - ethnicity_output_loss: 0.7607 - gender_output_loss: 0.2765 - ethnicity_output_accuracy: 0.7480 - ethnicity_output_weighted_accuracy: 0.7480 - gender_output_accuracy: 0.8844 - gender_output_weighted_accuracy: 0.8844 - val_loss: 0.9532 - val_ethnicity_output_loss: 0.6822 - val_gender_output_loss: 0.2711 - val_ethnicity_output_accuracy: 0.7631 - val_ethnicity_output_weighted_accuracy: 0.7631 - val_gender_output_accuracy: 0.8892 - val_gender_output_weighted_accuracy: 0.8892
# Epoch 4/200
# 868/868 [==============================] - 54s 63ms/step - loss: 0.8948 - ethnicity_output_loss: 0.6548 - gender_output_loss: 0.2400 - ethnicity_output_accuracy: 0.7891 - ethnicity_output_weighted_accuracy: 0.7891 - gender_output_accuracy: 0.9023 - gender_output_weighted_accuracy: 0.9023 - val_loss: 0.9644 - val_ethnicity_output_loss: 0.7061 - val_gender_output_loss: 0.2583 - val_ethnicity_output_accuracy: 0.7592 - val_ethnicity_output_weighted_accuracy: 0.7592 - val_gender_output_accuracy: 0.8923 - val_gender_output_weighted_accuracy: 0.8923
# Epoch 5/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.8040 - ethnicity_output_loss: 0.5912 - gender_output_loss: 0.2128 - ethnicity_output_accuracy: 0.8107 - ethnicity_output_weighted_accuracy: 0.8107 - gender_output_accuracy: 0.9122 - gender_output_weighted_accuracy: 0.9122 - val_loss: 0.8568 - val_ethnicity_output_loss: 0.6285 - val_gender_output_loss: 0.2283 - val_ethnicity_output_accuracy: 0.7908 - val_ethnicity_output_weighted_accuracy: 0.7908 - val_gender_output_accuracy: 0.9035 - val_gender_output_weighted_accuracy: 0.9035
# Epoch 6/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.7311 - ethnicity_output_loss: 0.5366 - gender_output_loss: 0.1945 - ethnicity_output_accuracy: 0.8281 - ethnicity_output_weighted_accuracy: 0.8281 - gender_output_accuracy: 0.9217 - gender_output_weighted_accuracy: 0.9217 - val_loss: 0.9053 - val_ethnicity_output_loss: 0.6397 - val_gender_output_loss: 0.2656 - val_ethnicity_output_accuracy: 0.7885 - val_ethnicity_output_weighted_accuracy: 0.7885 - val_gender_output_accuracy: 0.8950 - val_gender_output_weighted_accuracy: 0.8950
# Epoch 7/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.6653 - ethnicity_output_loss: 0.4879 - gender_output_loss: 0.1774 - ethnicity_output_accuracy: 0.8415 - ethnicity_output_weighted_accuracy: 0.8415 - gender_output_accuracy: 0.9301 - gender_output_weighted_accuracy: 0.9301 - val_loss: 0.9021 - val_ethnicity_output_loss: 0.6328 - val_gender_output_loss: 0.2693 - val_ethnicity_output_accuracy: 0.7977 - val_ethnicity_output_weighted_accuracy: 0.7977 - val_gender_output_accuracy: 0.8973 - val_gender_output_weighted_accuracy: 0.8973
# Epoch 8/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.6116 - ethnicity_output_loss: 0.4523 - gender_output_loss: 0.1593 - ethnicity_output_accuracy: 0.8510 - ethnicity_output_weighted_accuracy: 0.8510 - gender_output_accuracy: 0.9358 - gender_output_weighted_accuracy: 0.9358 - val_loss: 0.9278 - val_ethnicity_output_loss: 0.6760 - val_gender_output_loss: 0.2518 - val_ethnicity_output_accuracy: 0.8008 - val_ethnicity_output_weighted_accuracy: 0.8008 - val_gender_output_accuracy: 0.9069 - val_gender_output_weighted_accuracy: 0.9069
# Epoch 9/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.5745 - ethnicity_output_loss: 0.4237 - gender_output_loss: 0.1508 - ethnicity_output_accuracy: 0.8607 - ethnicity_output_weighted_accuracy: 0.8607 - gender_output_accuracy: 0.9400 - gender_output_weighted_accuracy: 0.9400 - val_loss: 0.9612 - val_ethnicity_output_loss: 0.6889 - val_gender_output_loss: 0.2723 - val_ethnicity_output_accuracy: 0.7969 - val_ethnicity_output_weighted_accuracy: 0.7969 - val_gender_output_accuracy: 0.9031 - val_gender_output_weighted_accuracy: 0.9031
# Epoch 10/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.5289 - ethnicity_output_loss: 0.3894 - gender_output_loss: 0.1395 - ethnicity_output_accuracy: 0.8712 - ethnicity_output_weighted_accuracy: 0.8712 - gender_output_accuracy: 0.9452 - gender_output_weighted_accuracy: 0.9452 - val_loss: 0.9064 - val_ethnicity_output_loss: 0.6399 - val_gender_output_loss: 0.2664 - val_ethnicity_output_accuracy: 0.8108 - val_ethnicity_output_weighted_accuracy: 0.8108 - val_gender_output_accuracy: 0.9015 - val_gender_output_weighted_accuracy: 0.9015
# Epoch 11/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.4841 - ethnicity_output_loss: 0.3542 - gender_output_loss: 0.1299 - ethnicity_output_accuracy: 0.8808 - ethnicity_output_weighted_accuracy: 0.8808 - gender_output_accuracy: 0.9499 - gender_output_weighted_accuracy: 0.9499 - val_loss: 0.9839 - val_ethnicity_output_loss: 0.7049 - val_gender_output_loss: 0.2790 - val_ethnicity_output_accuracy: 0.8012 - val_ethnicity_output_weighted_accuracy: 0.8012 - val_gender_output_accuracy: 0.9092 - val_gender_output_weighted_accuracy: 0.9092
# Epoch 12/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.4569 - ethnicity_output_loss: 0.3365 - gender_output_loss: 0.1204 - ethnicity_output_accuracy: 0.8864 - ethnicity_output_weighted_accuracy: 0.8864 - gender_output_accuracy: 0.9534 - gender_output_weighted_accuracy: 0.9534 - val_loss: 1.0702 - val_ethnicity_output_loss: 0.7495 - val_gender_output_loss: 0.3207 - val_ethnicity_output_accuracy: 0.7900 - val_ethnicity_output_weighted_accuracy: 0.7900 - val_gender_output_accuracy: 0.8900 - val_gender_output_weighted_accuracy: 0.8900
# Epoch 13/200
# 868/868 [==============================] - 54s 63ms/step - loss: 0.4338 - ethnicity_output_loss: 0.3184 - gender_output_loss: 0.1153 - ethnicity_output_accuracy: 0.8931 - ethnicity_output_weighted_accuracy: 0.8931 - gender_output_accuracy: 0.9557 - gender_output_weighted_accuracy: 0.9557 - val_loss: 1.1191 - val_ethnicity_output_loss: 0.7717 - val_gender_output_loss: 0.3474 - val_ethnicity_output_accuracy: 0.7946 - val_ethnicity_output_weighted_accuracy: 0.7946 - val_gender_output_accuracy: 0.9058 - val_gender_output_weighted_accuracy: 0.9058
# Epoch 14/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.6028 - ethnicity_output_loss: 0.4398 - gender_output_loss: 0.1630 - ethnicity_output_accuracy: 0.8531 - ethnicity_output_weighted_accuracy: 0.8531 - gender_output_accuracy: 0.9349 - gender_output_weighted_accuracy: 0.9349 - val_loss: 1.0797 - val_ethnicity_output_loss: 0.7578 - val_gender_output_loss: 0.3219 - val_ethnicity_output_accuracy: 0.7958 - val_ethnicity_output_weighted_accuracy: 0.7958 - val_gender_output_accuracy: 0.9119 - val_gender_output_weighted_accuracy: 0.9119
# Epoch 15/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.3903 - ethnicity_output_loss: 0.2882 - gender_output_loss: 0.1020 - ethnicity_output_accuracy: 0.9036 - ethnicity_output_weighted_accuracy: 0.9036 - gender_output_accuracy: 0.9607 - gender_output_weighted_accuracy: 0.9607 - val_loss: 1.3263 - val_ethnicity_output_loss: 0.9528 - val_gender_output_loss: 0.3735 - val_ethnicity_output_accuracy: 0.8012 - val_ethnicity_output_weighted_accuracy: 0.8012 - val_gender_output_accuracy: 0.9058 - val_gender_output_weighted_accuracy: 0.9058
# Epoch 16/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.3600 - ethnicity_output_loss: 0.2641 - gender_output_loss: 0.0959 - ethnicity_output_accuracy: 0.9116 - ethnicity_output_weighted_accuracy: 0.9116 - gender_output_accuracy: 0.9642 - gender_output_weighted_accuracy: 0.9642 - val_loss: 1.1017 - val_ethnicity_output_loss: 0.7736 - val_gender_output_loss: 0.3281 - val_ethnicity_output_accuracy: 0.8108 - val_ethnicity_output_weighted_accuracy: 0.8108 - val_gender_output_accuracy: 0.8969 - val_gender_output_weighted_accuracy: 0.8969
# Epoch 17/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.3451 - ethnicity_output_loss: 0.2542 - gender_output_loss: 0.0909 - ethnicity_output_accuracy: 0.9168 - ethnicity_output_weighted_accuracy: 0.9168 - gender_output_accuracy: 0.9661 - gender_output_weighted_accuracy: 0.9661 - val_loss: 1.3723 - val_ethnicity_output_loss: 0.9361 - val_gender_output_loss: 0.4362 - val_ethnicity_output_accuracy: 0.8000 - val_ethnicity_output_weighted_accuracy: 0.8000 - val_gender_output_accuracy: 0.9027 - val_gender_output_weighted_accuracy: 0.9027
# Epoch 18/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.3401 - ethnicity_output_loss: 0.2489 - gender_output_loss: 0.0912 - ethnicity_output_accuracy: 0.9167 - ethnicity_output_weighted_accuracy: 0.9167 - gender_output_accuracy: 0.9667 - gender_output_weighted_accuracy: 0.9667 - val_loss: 1.1665 - val_ethnicity_output_loss: 0.8803 - val_gender_output_loss: 0.2862 - val_ethnicity_output_accuracy: 0.8065 - val_ethnicity_output_weighted_accuracy: 0.8065 - val_gender_output_accuracy: 0.9069 - val_gender_output_weighted_accuracy: 0.9069
# Epoch 19/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.4161 - ethnicity_output_loss: 0.2973 - gender_output_loss: 0.1187 - ethnicity_output_accuracy: 0.9028 - ethnicity_output_weighted_accuracy: 0.9028 - gender_output_accuracy: 0.9564 - gender_output_weighted_accuracy: 0.9564 - val_loss: 1.1946 - val_ethnicity_output_loss: 0.8630 - val_gender_output_loss: 0.3316 - val_ethnicity_output_accuracy: 0.7742 - val_ethnicity_output_weighted_accuracy: 0.7742 - val_gender_output_accuracy: 0.9038 - val_gender_output_weighted_accuracy: 0.9038
# Epoch 20/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.3170 - ethnicity_output_loss: 0.2316 - gender_output_loss: 0.0854 - ethnicity_output_accuracy: 0.9209 - ethnicity_output_weighted_accuracy: 0.9209 - gender_output_accuracy: 0.9686 - gender_output_weighted_accuracy: 0.9686 - val_loss: 1.4867 - val_ethnicity_output_loss: 1.0981 - val_gender_output_loss: 0.3886 - val_ethnicity_output_accuracy: 0.7915 - val_ethnicity_output_weighted_accuracy: 0.7915 - val_gender_output_accuracy: 0.9019 - val_gender_output_weighted_accuracy: 0.9019
# Epoch 21/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2826 - ethnicity_output_loss: 0.2067 - gender_output_loss: 0.0759 - ethnicity_output_accuracy: 0.9329 - ethnicity_output_weighted_accuracy: 0.9329 - gender_output_accuracy: 0.9724 - gender_output_weighted_accuracy: 0.9724 - val_loss: 1.2524 - val_ethnicity_output_loss: 0.9022 - val_gender_output_loss: 0.3502 - val_ethnicity_output_accuracy: 0.7919 - val_ethnicity_output_weighted_accuracy: 0.7919 - val_gender_output_accuracy: 0.9042 - val_gender_output_weighted_accuracy: 0.9042
# Epoch 22/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2769 - ethnicity_output_loss: 0.2038 - gender_output_loss: 0.0731 - ethnicity_output_accuracy: 0.9347 - ethnicity_output_weighted_accuracy: 0.9347 - gender_output_accuracy: 0.9735 - gender_output_weighted_accuracy: 0.9735 - val_loss: 1.3897 - val_ethnicity_output_loss: 1.0507 - val_gender_output_loss: 0.3390 - val_ethnicity_output_accuracy: 0.8058 - val_ethnicity_output_weighted_accuracy: 0.8058 - val_gender_output_accuracy: 0.9031 - val_gender_output_weighted_accuracy: 0.9031
# Epoch 23/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2648 - ethnicity_output_loss: 0.1920 - gender_output_loss: 0.0728 - ethnicity_output_accuracy: 0.9375 - ethnicity_output_weighted_accuracy: 0.9375 - gender_output_accuracy: 0.9746 - gender_output_weighted_accuracy: 0.9746 - val_loss: 1.5212 - val_ethnicity_output_loss: 1.0288 - val_gender_output_loss: 0.4924 - val_ethnicity_output_accuracy: 0.7973 - val_ethnicity_output_weighted_accuracy: 0.7973 - val_gender_output_accuracy: 0.9012 - val_gender_output_weighted_accuracy: 0.9012
# Epoch 24/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2630 - ethnicity_output_loss: 0.1949 - gender_output_loss: 0.0681 - ethnicity_output_accuracy: 0.9362 - ethnicity_output_weighted_accuracy: 0.9362 - gender_output_accuracy: 0.9757 - gender_output_weighted_accuracy: 0.9757 - val_loss: 1.4294 - val_ethnicity_output_loss: 1.0106 - val_gender_output_loss: 0.4188 - val_ethnicity_output_accuracy: 0.7927 - val_ethnicity_output_weighted_accuracy: 0.7927 - val_gender_output_accuracy: 0.9100 - val_gender_output_weighted_accuracy: 0.9100
# Epoch 25/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2529 - ethnicity_output_loss: 0.1871 - gender_output_loss: 0.0658 - ethnicity_output_accuracy: 0.9399 - ethnicity_output_weighted_accuracy: 0.9399 - gender_output_accuracy: 0.9764 - gender_output_weighted_accuracy: 0.9764 - val_loss: 1.4770 - val_ethnicity_output_loss: 1.0957 - val_gender_output_loss: 0.3813 - val_ethnicity_output_accuracy: 0.8062 - val_ethnicity_output_weighted_accuracy: 0.8062 - val_gender_output_accuracy: 0.9012 - val_gender_output_weighted_accuracy: 0.9012
# Epoch 26/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2553 - ethnicity_output_loss: 0.1845 - gender_output_loss: 0.0708 - ethnicity_output_accuracy: 0.9412 - ethnicity_output_weighted_accuracy: 0.9412 - gender_output_accuracy: 0.9754 - gender_output_weighted_accuracy: 0.9754 - val_loss: 1.5369 - val_ethnicity_output_loss: 1.1176 - val_gender_output_loss: 0.4194 - val_ethnicity_output_accuracy: 0.8081 - val_ethnicity_output_weighted_accuracy: 0.8081 - val_gender_output_accuracy: 0.9031 - val_gender_output_weighted_accuracy: 0.9031
# Epoch 27/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2495 - ethnicity_output_loss: 0.1803 - gender_output_loss: 0.0692 - ethnicity_output_accuracy: 0.9428 - ethnicity_output_weighted_accuracy: 0.9428 - gender_output_accuracy: 0.9765 - gender_output_weighted_accuracy: 0.9765 - val_loss: 1.4743 - val_ethnicity_output_loss: 1.0639 - val_gender_output_loss: 0.4103 - val_ethnicity_output_accuracy: 0.7838 - val_ethnicity_output_weighted_accuracy: 0.7838 - val_gender_output_accuracy: 0.9038 - val_gender_output_weighted_accuracy: 0.9038
# Epoch 28/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2223 - ethnicity_output_loss: 0.1612 - gender_output_loss: 0.0612 - ethnicity_output_accuracy: 0.9489 - ethnicity_output_weighted_accuracy: 0.9489 - gender_output_accuracy: 0.9796 - gender_output_weighted_accuracy: 0.9796 - val_loss: 1.5575 - val_ethnicity_output_loss: 1.1325 - val_gender_output_loss: 0.4250 - val_ethnicity_output_accuracy: 0.7977 - val_ethnicity_output_weighted_accuracy: 0.7977 - val_gender_output_accuracy: 0.9069 - val_gender_output_weighted_accuracy: 0.9069
# Epoch 29/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2135 - ethnicity_output_loss: 0.1553 - gender_output_loss: 0.0581 - ethnicity_output_accuracy: 0.9511 - ethnicity_output_weighted_accuracy: 0.9511 - gender_output_accuracy: 0.9805 - gender_output_weighted_accuracy: 0.9805 - val_loss: 1.5107 - val_ethnicity_output_loss: 1.0374 - val_gender_output_loss: 0.4733 - val_ethnicity_output_accuracy: 0.8031 - val_ethnicity_output_weighted_accuracy: 0.8031 - val_gender_output_accuracy: 0.9012 - val_gender_output_weighted_accuracy: 0.9012
# Epoch 30/200
# 868/868 [==============================] - 54s 62ms/step - loss: 0.2315 - ethnicity_output_loss: 0.1682 - gender_output_loss: 0.0632 - ethnicity_output_accuracy: 0.9475 - ethnicity_output_weighted_accuracy: 0.9475 - gender_output_accuracy: 0.9789 - gender_output_weighted_accuracy: 0.9789 - val_loss: 1.6931 - val_ethnicity_output_loss: 1.3100 - val_gender_output_loss: 0.3830 - val_ethnicity_output_accuracy: 0.7842 - val_ethnicity_output_weighted_accuracy: 0.7842 - val_gender_output_accuracy: 0.9085 - val_gender_output_weighted_accuracy: 0.9085

# %%
plt.figure()
plt.plot(history.history['val_ethnicity_output_accuracy'], label='val_ac_ethnicity')
plt.plot(history.history['ethnicity_output_accuracy'], label='train_ac_ethnicity')
plt.plot(history.history['val_gender_output_accuracy'], label='val_ac_gender')
plt.plot(history.history['gender_output_accuracy'], label='train_ac_gender')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import model_from_json
# save model
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
  json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load model
json_file = open('model.json', 'r')

loaded_model_json = json_file.read()

json_file.close()

loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights("model.h5")

print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# Compile the loaded model
loaded_model.compile(optimizer='adam', loss=losses, metrics=metrics, weighted_metrics=metrics)

# Evaluate the loaded model on the test data for both outputs
score = loaded_model.evaluate(x=test_rgb_images, y={'ethnicity_output': test_label_races, 'gender_output': test_label_genders})

# Print the accuracies for gender and ethnicity
gender_accuracy_index = loaded_model.metrics_names.index('gender_output_accuracy')
ethnicity_accuracy_index = loaded_model.metrics_names.index('ethnicity_output_accuracy')
gender_accuracy = score[gender_accuracy_index]
ethnicity_accuracy = score[ethnicity_accuracy_index]

print("Gender Accuracy: %.2f%%" % (gender_accuracy * 100))
print("Ethnicity Accuracy: %.2f%%" % (ethnicity_accuracy * 100))
# Out:
# 82/82 [==============================] - 2s 17ms/step - loss: 1.9412 - ethnicity_output_loss: 1.5421 - gender_output_loss: 0.3992 - ethnicity_output_accuracy: 0.7735 - ethnicity_output_weighted_accuracy: 0.7735 - gender_output_accuracy: 0.8977 - gender_output_weighted_accuracy: 0.8977
# Gender Accuracy: 89.77%
# Ethnicity Accuracy: 77.35%

# %% [markdown]
# Receiver Operating Characteristic (ROC) Curve and Area Under the Curve (AUC)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Extract predicted probabilities for gender and ethnicity
y_hat_prob_scores = loaded_model.predict(x=test_rgb_images)
y_hat_prob_gender = y_hat_prob_scores[1]
y_hat_prob_ethnicity = y_hat_prob_scores[0]
# Out:
# 82/82 [==============================] - 2s 24ms/step

# %% [markdown]
# First, for the ethnicity:

# %%
from sklearn.metrics import roc_curve, auc
n_classes = y_hat_prob_ethnicity.shape[1]
# Compute the FPR, TPR, and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(test_label_races[:,i], y_hat_prob_ethnicity[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(test_label_races.ravel(), y_hat_prob_ethnicity.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# Compute macro-average ROC curve and AUC
# It seems there is a mismatch in the shape
# of the FPR and TPR arrays for different classes,
# causing the ValueError when trying to calculate the mean.
# To resolve this issue, you can interpolate the FPR and TPR arrays
# to have the same length before calculating the mean.

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
# Then interpolate all ROC curves at these points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='Micro-average (auc={0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=2)

plt.plot(fpr["macro"], tpr["macro"],
         label='Macro-average (auc={0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=2)

for i in range(5):
    plt.plot(fpr[i], tpr[i], lw=2,
             label='Class {0} (auc={1:0.2f})'
             ''.format(labels_races[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Compute confusion matrix
cm = confusion_matrix(test_label_races.argmax(axis=1), y_hat_prob_ethnicity.argmax(axis=1))

# Create class labels
class_labels = [str(labels_races[i]) for i in range(n_classes)]

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)

plt.title('Confusion Matrix for Ethnicity')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# Let's do the same thing for the evaluation of gender classification

# %%
n_classes = y_hat_prob_gender.shape[1]
# Compute the FPR, TPR, and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
test_label_genders = test_label_genders[:, np.newaxis]
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(test_label_genders[:,i], y_hat_prob_gender[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(test_label_genders, y_hat_prob_gender.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
# Then interpolate all ROC curves at these points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
mean_tpr /= n_classes
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='Micro-average (auc={0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=2)

plt.plot(fpr["macro"], tpr["macro"],
         label='Macro-average (auc={0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=2)

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2,
             label='Class {0} (auc={1:0.2f})'
             ''.format(labels_genders[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Test on different images

# %%
test_im = test_rgb_images[10]
test_im = test_im[np.newaxis, :]
predictions = loaded_model.predict(test_im)
if predictions[1] >= 0.5:
  predicted_gender = 1
else:
  predicted_gender = 0

predicted_ethnicity = np.argmax(predictions[0])
plt.imshow(test_im[0,:,:,0], cmap='gray')
plt.title(f"Predicted Gender: {labels_genders[predicted_gender]}, Predicted Ethnicity: {labels_races[predicted_ethnicity]}")
plt.show()
# Out:
# 1/1 [==============================] - 0s 85ms/step

# %%
random_numbers = np.random.randint(low=0, high=test_rgb_images.shape[0], size=20)
count = 0
predicted_ethnicity = []
predicted_gender = []
for k in random_numbers:
  fig.add_subplot(4,5,count+1)
  test_im = test_rgb_images[k]
  test_im = test_im[np.newaxis, :]
  predictions = loaded_model.predict(test_im)
  if predictions[1] >= 0.5:
    predicted_gender.append(1)
  else:
    predicted_gender.append(0)
  predicted_ethnicity.append(np.argmax(predictions[0]))
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
fig = plt.figure(figsize=(20,20))
count = 0
for i in random_numbers:
  fig.add_subplot(4,5,count+1)
  test_im = test_rgb_images[i]
  test_im = test_im[np.newaxis, :]
  plt.imshow(test_im[0,:,:,0], cmap='gray')
  plt.title(f"Predicted Gender: {labels_genders[predicted_gender[count]]},\n Predicted Ethnicity: {labels_races[predicted_ethnicity[count]]}")
  fig.tight_layout(pad=0.2)
  count += 1

# %% [markdown]
# Let's see the predictions on my face:

# %%
image_url = "https://media.licdn.com/dms/image/C4E03AQGoSN-Tvr-sfw/profile-displayphoto-shrink_800_800/0/1566002174950?e=1692230400&v=beta&t=vn8Z8DhReRDE_4af226aD40FQ4ySGyVHHH-6hHc0mOI"

# %%
import requests
from io import BytesIO
from PIL import Image
image_url_resp = requests.get(image_url)
image = Image.open(BytesIO(image_url_resp.content)).convert('L') # convert to grayscale
image = image.resize((48,48))
image = np.array(image, dtype="float32") / 255.0 # normalize pixel values to [0, 1]
image = np.expand_dims(image, axis=-1) # add an extra dimension for the single channel

print(image.shape)
# Out:
# (48, 48, 1)

# %%
rgb_image = np.stack((image,) * 3, axis=-1) / 255.0
rgb_image = np.squeeze(rgb_image)
rgb_image = rgb_image[np.newaxis, :]
print(rgb_image.shape)
# Out:
# (1, 48, 48, 3)

# %%
predictions = loaded_model.predict(rgb_image)
if predictions[1] >= 0.5:
  predicted_gender = 1
else:
  predicted_gender = 0
predicted_ethnicity = np.argmax(predictions[0])
# Out:
# 1/1 [==============================] - 0s 35ms/step

# %%
plt.figure(figsize = (5,5))
plt.imshow(rgb_image[0,:,:,0], cmap='gray')
plt.title(f"Predicted Gender: {labels_genders[predicted_gender]},\n Predicted Ethnicity: {labels_races[predicted_ethnicity]}")
plt.show()

# %% [markdown]
# Actually, I am not completely white, so let's see other predictions for ethnicity:

# %%
prd = []
for i in range(len(predictions[0][0])):
  prd.append(predictions[0][0][i])
plt.figure()
plt.bar(labels_races, prd)
plt.xlabel('Ethnicity')
plt.ylabel('Prediction')
plt.title('The predicted probabilities of races on my image')
plt.show()
